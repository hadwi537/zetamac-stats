# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.plot(range(10))
fig.savefig('temp.png', transparent=True)

# %%
import

# %%
import pandas as pd
data = pd.read_csv('./data.csv')
data.tail(10)
# Out:
#                       time  score
# 4   17-Dec-2021 (15:31:04)     10
# 5   17-Dec-2021 (15:35:22)      9
# 6   17-Dec-2021 (15:40:28)      8
# 7   17-Dec-2021 (16:00:37)      1
# 8   17-Dec-2021 (16:04:56)      0
# 9   17-Dec-2021 (16:05:32)      0
# 10  17-Dec-2021 (16:06:08)      0
# 11  17-Dec-2021 (16:16:54)      8
# 12  17-Dec-2021 (16:17:29)      3
# 13  17-Dec-2021 (16:23:06)      6

# %%
from matplotlib import pyplot as plt

data.tail(10).plot()
# Out:
# <AxesSubplot:>

# %%
ax = plt.axes()

ax.tick_params(axis='x', colors='red')
ax.tick_params(axis='y', colors='red')

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('./data.csv')

x = [x for x in range(1,11)]

# %%
import
